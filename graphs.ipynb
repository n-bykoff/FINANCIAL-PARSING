# %%
from modules.graphs_maker import *
ticker = 'SNAP'

# %% [markdown]
# ## Цена акции

# %%
stock_price(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Выручка и прибыль

# %%
quarterly_total_revenue(ticker)
quarterly_net_income(ticker)
quarterly_gross_margine(ticker)
quarterly_operating_margine(ticker)

# %% [markdown]
# ## Денежные потоки (операционный, инвестиционный, чистый)

# %%
quarterly_operating_cash_flow(ticker)
quarterly_investing_cash_flow(ticker)
quarterly_ocf_icf(ticker)
quarterly_financing_cash_flow(ticker)
quarterly_net_cash_flow(ticker)

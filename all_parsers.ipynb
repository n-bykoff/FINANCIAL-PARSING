# %% [markdown]
# # Financial Parser
#
# some description here...

# %% [markdown]
# ## All imports from modules path

# %%
# import my personal modules
from modules import finviz_parser as fp
from modules import dividends_parser as dp
from modules import finviz_screener_parser as fsp

# %%
import yfinance as yf
import pandas as pd
import time
import os

# %% [markdown]
# ## Finviz parsing part

# %% [markdown]
# In this part I parse info from finviz.com with beautiful soup and selenium modules.
#
# * parsing finviz.com screener
#
# * parsing yahoo finance
#
# * parsing dividends info
#
# * parsing elite.finviz.com
#     - quarterly reports
#     - yearly reports
#
# * parsing CEO info

# %%
data = pd.read_excel('./data/Screener tests.xlsx')
top_data = data[data['Cap M$'] != 'No data on finviz'][:100]
tickers = list(top_data['Все'])

# %% [markdown]
# ### finviz.com screener parsing

# %%
screener_df = fsp.parse_screener()
screener_df = fsp.market_cap_handler(screener_df)
screener_df
# Out:
#    Ticker                          Company              Sector  \
# 0    SNDL             Sundial Growers Inc.          Healthcare
# 1    PLTR       Palantir Technologies Inc.          Technology
# 2    WATT             Energous Corporation          Technology
# 3    ONTX      Onconova Therapeutics, Inc.          Healthcare
# 4    CTRM             Castor Maritime Inc.         Industrials
# ..    ...                              ...                 ...
# 95    SAN            Banco Santander, S.A.           Financial
# 96   COTY                        Coty Inc.  Consumer Defensive
# 97   TIGR       UP Fintech Holding Limited           Financial
# 98    NLY  Annaly Capital Management, Inc.         Real Estate
# 99   SUPV           Grupo Supervielle S.A.           Financial
#
#                                     Industry    Country Market Cap, M     P/E  \
# 0   Drug Manufacturers - Specialty & Generic     Canada         27100       -
# 1                  Software - Infrastructure        USA        524200       -
# 2         Scientific & Technical Instruments        USA           315       -
# 3                              Biotechnology        USA           338       -
# 4                            Marine Shipping     Cyprus           615       -
# ..                                       ...        ...           ...     ...
# 95                       Banks - Diversified      Spain        630200       -
# 96             Household & Personal Products        USA         60400       -
# 97                           Capital Markets      China         45800  672.69
# 98                           REIT - Mortgage        USA        116300       -
# 99                          Banks - Regional  Argentina           323    4.84
#
#     Price  Change       Volume
# 0    1.53   5.52%  866,543,568
# 1   29.00  15.22%  316,135,227
# 2    7.23  94.35%  176,508,809
# 3    1.63  -7.10%   95,444,109
# 4    1.21   0.00%   88,635,647
# ..    ...     ...          ...
# 95   3.64   3.70%   16,771,842
# 96   7.69   7.70%   16,620,194
# 97  34.98  11.33%   16,499,222
# 98   8.34   1.71%   16,360,439
# 99   2.36  -1.26%   15,979,250
#
# [100 rows x 10 columns]

# %% [markdown]
# ### finance.yahoo.com parsing

# %%
datas_dict = {}
all_data = pd.DataFrame(columns=['Ticker', 'Type', 'Value, $'])

# %%
for ticker in tickers:
    data = yf.download(ticker,'2020-01-01','2020-12-31')
    datas_dict[ticker] = data
    
    for i in range(5):
        new_data = pd.DataFrame(columns=['Ticker', 'Type', 'Value, $'], index=data.index)

        new_data['Ticker'] = ticker

        new_data['Type'] = data.columns[i]
        new_data['Value, $'] = data[data.columns[i]]
        all_data = pd.concat([all_data, new_data])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
all_data.index.name = 'Date'
all_data = all_data.sort_values(['Date', 'Ticker', 'Type'], ascending=[True, True, False])

# %%
all_data
# Out:
#            Ticker       Type    Value, $
# Date
# 2019-12-31   AAPL       Open   72.482498
# 2019-12-31   AAPL        Low   72.379997
# 2019-12-31   AAPL       High   73.419998
# 2019-12-31   AAPL      Close   73.412498
# 2019-12-31   AAPL  Adj Close   72.675339
# ...           ...        ...         ...
# 2020-12-30     ZM       Open  358.420013
# 2020-12-30     ZM        Low  345.399994
# 2020-12-30     ZM       High  358.700012
# 2020-12-30     ZM      Close  353.399994
# 2020-12-30     ZM  Adj Close  353.399994
#
# [125305 rows x 3 columns]

# %%
all_data.to_csv('./data/quotes_2020.csv')

# %% [markdown]
# ### dividends.com info parsing

# %%
df_dic = {}

for ticker in tickers:
    
    try:
        text = dp.get_text(dp.go_to_search_page(), ticker)
        div_dic = dp.reshape_div_dic(dp.make_div_dic(text))

        df_dic[ticker] = dp.make_df(div_dic)
    except:
        print(f'{ticker} - no dividends info')
# Out:
# AMZN - no dividends info
# GOOG - no dividends info
# GOOGL - no dividends info
# TSLA - no dividends info
# FB - no dividends info
# BABA - no dividends info
# BRK-B - no dividends info
# BRK-A - no dividends info
# PYPL - no dividends info
# VZ - no dividends info
# ADBE - no dividends info
# NFLX - no dividends info
# PDD - no dividends info
# CRM - no dividends info
# ORCL - no dividends info
# TMUS - no dividends info
# SHOP - no dividends info
# JD - no dividends info
# CHTR - no dividends info
# BA - no dividends info
# SE - no dividends info
# ZM - no dividends info
# AMD - no dividends info
# ABNB - no dividends info
# RTX - no dividends info

# %%
df_dic['PG']
# Out:
#        PAY DATE DECLARED DATE EX-DIVIDEND DATE  PAYOUT AMOUNT  \
# 0    2020-11-16    2020-10-13       2020-10-22         0.7907
# 1    2020-08-17    2020-07-14       2020-07-23         0.7907
# 2    2020-05-15    2020-04-14       2020-04-23         0.7907
# 3    2020-02-18    2020-01-14       2020-01-23         0.7907
# 4    2019-11-15    2019-10-08       2019-10-17         0.7907
# ..          ...           ...              ...            ...
# 107  1994-02-15    1994-01-11       1994-01-14         0.7907
# 108  1993-11-15    1993-10-12       1993-10-18         0.7907
# 109  1993-08-16    1993-07-15       1993-07-19         0.7907
# 110  1993-05-14    1993-04-13       1993-04-19         0.7907
# 111  1993-02-16    1993-01-12       1993-01-15         0.7907
#
#     QUALIFIED DIVIDEND? PAYOUT TYPE  FREQUENCY  \
# 0     Income, Qualified     Regular  Quarterly
# 1     Income, Qualified     Regular  Quarterly
# 2     Income, Qualified     Regular  Quarterly
# 3     Income, Qualified     Regular  Quarterly
# 4     Income, Qualified     Regular  Quarterly
# ..                  ...         ...        ...
# 107              Income     Regular  Quarterly
# 108              Income     Regular  Quarterly
# 109              Income     Regular  Quarterly
# 110              Income     Regular  Quarterly
# 111              Income     Regular  Quarterly
#
#     DAYS TAKEN FOR STOCK PRICE TO RECOVER
# 0                                      16
# 1                                       0
# 2                                       0
# 3                                       9
# 4                                       2
# ..                                    ...
# 107                                     0
# 108                                     7
# 109                                    63
# 110                                     6
# 111                                     0
#
# [112 rows x 8 columns]

# %%
os.mkdir('./data/dividends')

for key in df_dic.keys():
    df_dic[key].to_csv(f'./data/dividends/{key}_dividends_history.csv')

# %% [markdown]
# ### elite.finviz.com parsing

# %%
email = 'Podolskiyant@gmail.com'
password = '9w3msoidofyi'

# %%
os.mkdir('./data/quarterly_reports')
os.mkdir('./data/yearly_reports')

# %%
wd = fp.login_on_finviz(email, password)

for ticker in tickers:    
    wd = fp.go_to_company_page(wd, ticker)
    
    try:
        yearly_table_list = fp.get_table_list(wd)
        yearly_df = fp.make_yearly_df(yearly_table_list, wd)
        yearly_df.to_excel(f'./data/yearly_reports/{ticker}_yearly_report.xlsx')
        print(f'{ticker} yearly - DONE!')
        time.sleep(2)
    except:
        print(f'{ticker} yearly - FAILED!')
        
    try:
        wd = fp.quarterly_table(wd)
        table_list = fp.get_table_list(wd)
        df = fp.make_df(table_list, wd)
        df.to_excel(f'./data/quarterly_reports/{ticker}_quarterly_report.xlsx')
        print(f'{ticker} quarterly - DONE!')
        time.sleep(3)
    except:
        print(f'{ticker} quarterly - FAILED!')
    
wd.close()
# Out:
# AAPL yearly - DONE!
# AAPL quarterly - DONE!
# MSFT yearly - DONE!
# MSFT quarterly - DONE!
# AMZN yearly - DONE!
# AMZN quarterly - DONE!
# GOOG yearly - DONE!
# GOOG quarterly - DONE!
# GOOGL yearly - DONE!
# GOOGL quarterly - DONE!
# TSLA yearly - DONE!
# TSLA quarterly - DONE!
# FB yearly - DONE!
# FB quarterly - DONE!
# BABA yearly - DONE!
# BABA quarterly - DONE!
# BRK-B yearly - DONE!
# BRK-B quarterly - DONE!
# BRK-A yearly - DONE!
# BRK-A quarterly - DONE!
# TSM yearly - DONE!
# TSM quarterly - DONE!
# V yearly - DONE!
# V quarterly - DONE!
# JPM yearly - DONE!
# JPM quarterly - DONE!
# JNJ yearly - DONE!
# JNJ quarterly - DONE!
# WMT yearly - DONE!
# WMT quarterly - DONE!
# PG yearly - DONE!
# PG quarterly - DONE!
# UNH yearly - DONE!
# UNH quarterly - DONE!
# NVDA yearly - DONE!
# NVDA quarterly - DONE!
# MA yearly - DONE!
# MA quarterly - DONE!
# DIS yearly - DONE!
# DIS quarterly - DONE!
# BAC yearly - DONE!
# BAC quarterly - DONE!
# HD yearly - DONE!
# HD quarterly - DONE!
# PYPL yearly - DONE!
# PYPL quarterly - DONE!
# TM yearly - DONE!
# TM quarterly - DONE!
# INTC yearly - DONE!
# INTC quarterly - DONE!
# VZ yearly - DONE!
# VZ quarterly - DONE!
# NVS yearly - DONE!
# NVS quarterly - DONE!
# ASML yearly - DONE!
# ASML quarterly - DONE!
# CMCSA yearly - DONE!
# CMCSA quarterly - DONE!
# NKE yearly - DONE!
# NKE quarterly - DONE!
# ADBE yearly - DONE!
# ADBE quarterly - DONE!
# NFLX yearly - DONE!
# NFLX quarterly - DONE!
# XOM yearly - DONE!
# XOM quarterly - DONE!
# KO yearly - DONE!
# KO quarterly - DONE!
# T yearly - DONE!
# T quarterly - DONE!
# MRK yearly - DONE!
# MRK quarterly - DONE!
# PDD yearly - FAILED!
# PDD quarterly - DONE!
# PFE yearly - DONE!
# PFE quarterly - DONE!
# CRM yearly - DONE!
# CRM quarterly - DONE!
# ABBV yearly - DONE!
# ABBV quarterly - DONE!
# TMO yearly - DONE!
# TMO quarterly - DONE!
# PEP yearly - DONE!
# PEP quarterly - DONE!
# ABT yearly - DONE!
# ABT quarterly - DONE!
# CSCO yearly - DONE!
# CSCO quarterly - DONE!
# AVGO yearly - DONE!
# AVGO quarterly - DONE!
# CVX yearly - DONE!
# CVX quarterly - DONE!
# QCOM yearly - DONE!
# QCOM quarterly - DONE!
# ORCL yearly - DONE!
# ORCL quarterly - DONE!
# LLY yearly - DONE!
# LLY quarterly - DONE!
# ACN yearly - DONE!
# ACN quarterly - DONE!
# BBL yearly - DONE!
# BBL quarterly - DONE!
# BHP yearly - DONE!
# BHP quarterly - DONE!
# DHR yearly - DONE!
# DHR quarterly - DONE!
# NEE yearly - DONE!
# NEE quarterly - DONE!
# COST yearly - DONE!
# COST quarterly - DONE!
# MDT yearly - DONE!
# MDT quarterly - DONE!
# RDS-A yearly - DONE!
# RDS-A quarterly - DONE!
# TXN yearly - DONE!
# TXN quarterly - DONE!
# UL yearly - DONE!
# UL quarterly - DONE!
# SAP yearly - DONE!
# SAP quarterly - DONE!
# MCD yearly - DONE!
# MCD quarterly - DONE!
# TMUS yearly - DONE!
# TMUS quarterly - DONE!
# BMY yearly - DONE!
# BMY quarterly - DONE!
# LFC yearly - DONE!
# LFC quarterly - DONE!
# HON yearly - DONE!
# HON quarterly - DONE!
# UNP yearly - DONE!
# UNP quarterly - DONE!
# SHOP yearly - DONE!
# SHOP quarterly - DONE!
# C yearly - DONE!
# C quarterly - DONE!
# WFC yearly - DONE!
# WFC quarterly - DONE!
# JD yearly - DONE!
# JD quarterly - DONE!
# UPS yearly - DONE!
# UPS quarterly - DONE!
# RDS-B yearly - DONE!
# RDS-B quarterly - DONE!
# AMGN yearly - DONE!
# AMGN quarterly - DONE!
# RIO yearly - DONE!
# RIO quarterly - DONE!
# MS yearly - DONE!
# MS quarterly - DONE!
# LIN yearly - DONE!
# LIN quarterly - DONE!
# HDB yearly - DONE!
# HDB quarterly - DONE!
# AZN yearly - DONE!
# AZN quarterly - DONE!
# SNE yearly - DONE!
# SNE quarterly - DONE!
# NVO yearly - DONE!
# NVO quarterly - DONE!
# PM yearly - DONE!
# PM quarterly - DONE!
# LOW yearly - DONE!
# LOW quarterly - DONE!
# CHTR yearly - DONE!
# CHTR quarterly - DONE!
# SNY yearly - DONE!
# SNY quarterly - DONE!
# TOT yearly - DONE!
# TOT quarterly - DONE!
# RY yearly - FAILED!
# RY quarterly - FAILED!
# SBUX yearly - DONE!
# SBUX quarterly - DONE!
# BA yearly - DONE!
# BA quarterly - DONE!
# BUD yearly - DONE!
# BUD quarterly - DONE!
# SE yearly - FAILED!
# SE quarterly - DONE!
# PTR yearly - DONE!
# PTR quarterly - DONE!
# IBM yearly - DONE!
# IBM quarterly - DONE!
# BLK yearly - DONE!
# BLK quarterly - DONE!
# HSBC yearly - DONE!
# HSBC quarterly - FAILED!
# ZM yearly - FAILED!
# ZM quarterly - DONE!
# SCHW yearly - DONE!
# SCHW quarterly - DONE!
# AMD yearly - DONE!
# AMD quarterly - DONE!
# ABNB yearly - FAILED!
# ABNB quarterly - DONE!
# TD yearly - FAILED!
# TD quarterly - FAILED!
# RTX yearly - DONE!
# RTX quarterly - DONE!
